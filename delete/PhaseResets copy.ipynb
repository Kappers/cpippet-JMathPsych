# %%
import collections
import copy
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import linregress
from matplotlib.ticker import FormatStrFormatter

# %%
import PIPPET
import utils

# %%
#%matplotlib inline
# %config InlineBackend.figure_formats = ['svg']

plt.style.use('default')

plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 600
plt.rcParams['figure.autolayout'] = False
plt.rcParams['font.size'] = 8
plt.rcParams['legend.fontsize'] = 8
sns.set_context('paper', font_scale=0.9)

# %% [markdown]
# # Fitch & Rosenfeld (2007) rhythms

# %%
# [[rhythm], syncopation index, rhythm number]
from fitchrosenfeld_stimuli import FR2007_RHYTHMS

# %%
# "46 pulses", so 11 reps -> 46 * 60/110 = 25s, 46 * 60/75 = 36.8s
NOME_MEASURES = 2
STIM_REPS = 3

# %%
def to_times(bits):
    e_ts = ((np.ones(len(bits)) * 0.25).cumsum() - 0.25)[np.array(bits) > 0]
    return e_ts

fr_stims = []
for bits, _, _ in FR2007_RHYTHMS:
    bits_stim = ([1, 0, 0, 0] * 4 * NOME_MEASURES) + bits * STIM_REPS
    fr_stims.append(2*np.pi * to_times(bits_stim))

# %%
syncopation_scores = np.array([r[1] for r in FR2007_RHYTHMS])

# %% [markdown]
# # Simulations

# %%
p = PIPPET.PIPPETParams()
p.dt = 0.005
p.overtime = np.pi/2
p.lambda_0 = 0.001
p.sigma_phi = 0.2
p.mu_0 = 0
p.V_0 = 0.1
p.eta_mu = 0.00
p.eta_e = 0.0
p.eta_V = 0.00
e_means   = np.array([0.0])
e_vars    = np.array([0.01])
e_lambdas = np.array([0.01])

# %%
models = []
for stim in fr_stims:
    p_ = copy.deepcopy(p)
    p_.add(stim, e_means, e_vars, e_lambdas, '')
    m = PIPPET.cPIPPET(p_)
    models.append(m)

# %%
for i, m in enumerate(models):
    m.run()

# %% [markdown]
# ### Resetting statistics

# %%
all_ts = []
sync_counts = collections.Counter()
reset_perc = collections.defaultdict(float)
for sync, m in zip(syncopation_scores, models):
    # Find 0-crossings on phase
    inds = np.where((np.roll(m.mu_s, 1) < 0) & (m.mu_s > 0))[0]
    ts = m.ts[inds]
    all_ts.append(ts)
    # Check whether 0-crossings are closer to beats, or off-beats
    beats = np.arange(2*np.pi, m.tmax, 2*np.pi)
    offbeats = np.arange(np.pi, m.tmax, 2*np.pi)
    agg = 0
    for t in ts:
        agg += int(np.min(np.abs(beats - t)) > np.min(np.abs(offbeats - t)))
    reset_perc[sync] += agg/len(ts)
    sync_counts[sync] += 1
for sync, count in sync_counts.items():
    reset_perc[sync] /= count

# %%
syncs, perc = zip(*reset_perc.items())
syncs, perc = list(syncs), list(perc)

# %%
lin = linregress(syncs, perc)
lin.rvalue, lin.pvalue
# Out:
# (0.8838464028084548, 5.597126173687937e-06)

# %% [markdown]
# ### Resets & Phase Alignment

# %%
fig = plt.figure(figsize=(6, 4))
ax = fig.gca()
sns.regplot(x=syncs, y=np.array(perc)*100, order=1, color='dimgrey', ax=ax, robust=True)
ax.set_xlabel('Syncopation index (LHL)', fontsize=10, labelpad=5)
ax.set_ylabel('Tracking off-beat (% of stimulus)', fontsize=10, labelpad=5)
ax.set_ylim([-2, None])

fig.savefig('figures/fig_phasereset.pdf', bbox_inches='tight');
# Out:
# /Users/thomaskaplan/libs/venv/lib/python3.8/site-packages/statsmodels/compat/pandas.py:65: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import Int64Index as NumericIndex

# %% [markdown]
# ### Examples

# %%
# Phase
def _plot_phase(ax, model, from_i, to_i, col, offset=0):
    # Phase progress
    std = 2*np.sqrt(model.V_s[from_i:to_i])
    ax.plot(model.ts[from_i:to_i], model.mu_s[from_i:to_i]+offset, c=col, linewidth=1.75)
    ax.fill_between(model.ts[from_i:to_i], model.mu_s[from_i:to_i]+offset-std, model.mu_s[from_i:to_i]+offset+std, alpha=0.2, facecolor=col)
def _plot_phase_wraps(ax, model, col):
    # Find wrapping points
    xs = model.mu_s
    wrap_is = np.where((np.roll(np.sign(xs), 1) != np.sign(xs)) & (np.abs(xs) > 3.1))[0]
    prev_from = 0
    for i, wrap_i in enumerate(wrap_is):
        from_i = wrap_is[i-1] if i > 0 else 0
        to_i = wrap_is[i+1] if i < len(wrap_is)-1 else model.mu_s.size+1
        _plot_phase(ax, model, from_i, wrap_i, col)
        _plot_phase(ax, model, from_i, wrap_i, col, offset=-2*np.pi)
        _plot_phase(ax, model, wrap_i, to_i, col, offset=2*np.pi)
    _plot_phase(ax, model, wrap_is[-1], model.mu_s.size+1, col)
    
    
def _plot_example(ax, ax_temp, model, tmax=None):

    cs_b = ['deepskyblue', 'lightcoral']
    
    # Template
    utils.plot_template(model, ax_temp, ['black'], xlabelkwargs={'fontsize': 10, 'labelpad': 10}, ylabelkwargs={'fontsize': 10})

    # Stimulus/Auditory events
    #utils.plot_events(model, ax, ax_temp, cols=['lightgray'], stimulus=False, expected=True)
    # Events
    ax.vlines(model.ts[list(model.idx_event)], -np.pi, np.pi, color='dimgray', alpha=0.9, linestyle='--', linewidth=1, label='Stimulus events')

    # Phase progress
    _plot_phase_wraps(ax, model, 'black')
    ax.set_xlabel('Time', fontsize=10, labelpad=10)

    # Beats
    ax.scatter(np.arange(20)*2*np.pi, [0]*20, color=cs_b[0], alpha=1, marker='o', s=50, label='Stimulus beats')
    # Offbeats
    ax.scatter(np.arange(20)*2*np.pi + np.pi, [0]*20, color=cs_b[1], alpha=1, marker='o', s=50, label='Stimulus off-beats')

    # Tidying
    if tmax is None:
        tmax = model.tmax
    ax.set_xlim([model.ts[list(sorted(model.idx_event))[4*NOME_MEASURES - 1]], tmax])
    #ax.set_xlim([0, model.tmax])
    ax.set_ylim([-np.pi, np.pi])
    #ax.axhline(-np.pi/2, color='grey', alpha=0.33, linestyle='--', linewidth=1)
    #ax.axhline(np.pi/2, color='grey', alpha=0.33, linestyle='--', linewidth=1)

    ax.xaxis.set_major_formatter(FormatStrFormatter('%.1f'))
    ax_temp.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    plt.setp(ax.get_yticklabels(), visible=False)
    ax.tick_params(axis='both', which='major', labelsize=8)
    ax_temp.tick_params(axis='both', which='major', labelsize=8)

    ax_temp.set_yticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
    ax_temp.set_yticklabels([r'$-\,\pi$', r'$-\,\frac{\pi}{2}$', r'$0$', r'$\frac{\pi}{2}$', r'$\pi$'], fontsize=12)

    leg = ax.legend(edgecolor='k', loc='upper left')
    leg.get_frame().set_alpha(None)
    
    
def _plot_rose(ax, xs, col):

    # Force bins to partition entire circle
    bins = np.linspace(-np.pi, np.pi, num=16)

    # Wrap angles to [-pi, pi)
    xs = (xs+np.pi) % (2*np.pi) - np.pi
    # Bin data and record counts
    n, bins = np.histogram(xs, bins=bins)
    widths = np.diff(bins)
    # Area to assign each bin
    area = n / xs.size
    # Calculate corresponding bin radius
    radius = (area/np.pi) ** .5
    patches = ax.bar(bins[:-1], radius, zorder=1, align='edge', width=widths,
                     color=col, edgecolor=col, fill=True, alpha=0.9, linewidth=1)

    ax.set_theta_offset(0)
    ax.set_yticks([])

    ax.grid(linewidth=1, linestyle='-.', color='lightgray', alpha=0.5)
    xL = ['0', r'$\frac{\pi}{4}$',r'$\frac{\pi}{2}$',r'$\frac{3\pi}{4}$',
               r'$\pm\pi$',r'$-\,\frac{3\pi}{4}$',r'$-\,\frac{\pi}{2}$',r'$-\,\frac{\pi}{4}$']
    ax.set_xticklabels(xL, fontsize=10)
    ax.set_xlabel('Phase alignment across stimulus', fontsize=10, labelpad=8)
    
    ax.set_rlim([0, .65])

# %%
fig = plt.figure(figsize=(12, 6))

gs = fig.add_gridspec(2, 2, height_ratios=(1, 1), width_ratios=(4.5, 1), wspace=0.15, hspace=0.6)

# Phase

gs_1 = gs[0].subgridspec(1, 2, width_ratios=(1, 6), wspace=0.05)
gs_2 = gs[2].subgridspec(1, 2, width_ratios=(1, 6), wspace=0.05)

ax_1 = fig.add_subplot(gs_1[1])
ax_temp_1 = fig.add_subplot(gs_1[0], sharey=ax_1)
_plot_example(ax_1, ax_temp_1, models[0])


ax_2 = fig.add_subplot(gs_2[1])
ax_temp_2 = fig.add_subplot(gs_2[0], sharey=ax_2)
_plot_example(ax_2, ax_temp_2, models[10])

ax_temp_1.annotate('A', xy=(-0.04, np.pi*1.1), fontsize=14, annotation_clip=False)
ax_temp_2.annotate('B', xy=(-0.04, np.pi*1.1), fontsize=14, annotation_clip=False)

# Rose

ax_1p = fig.add_subplot(gs[1], projection='polar')
model = models[0]
start_from = model.ts[list(sorted(model.idx_event))[4*NOME_MEASURES - 1]]
ts = all_ts[0][np.where(all_ts[0] > start_from)[0]]
_plot_rose(ax_1p, ts, 'slategrey')

ax_2p = fig.add_subplot(gs[3], projection='polar')
model = models[10]
start_from = model.ts[list(sorted(model.idx_event))[4*NOME_MEASURES - 1]]
ts = all_ts[10][np.where(all_ts[10] > start_from)[0]]
_plot_rose(ax_2p, ts, 'slategrey')


#fig.savefig('figures/fig_phasereset_examples.jpeg', bbox_inches='tight');
pass
# Out:
# ---------------------------------------------------------------------------
# DeprecationWarning                        Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 fig = plt.figure(figsize=(12, 6))
#       3 gs = fig.add_gridspec(2, 2, height_ratios=(1, 1), width_ratios=(4.5, 1), wspace=0.15, hspace=0.6)
#       5 # Phase
#
# File ~/opt/miniconda3/envs/jon_current_env/lib/python3.11/site-packages/matplotlib/pyplot.py:934, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     924 if len(allnums) == max_open_warning >= 1:
#     925     _api.warn_external(
#     926         f"More than {max_open_warning} figures have been opened. "
#     927         f"Figures created through the pyplot interface "
#    (...)
#     931         f"Consider using `matplotlib.pyplot.close()`.",
#     932         RuntimeWarning)
# --> 934 manager = new_figure_manager(
#     935     num, figsize=figsize, dpi=dpi,
#     936     facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#     937     FigureClass=FigureClass, **kwargs)
#     938 fig = manager.canvas.figure
#     939 if fig_label:
#
# File ~/opt/miniconda3/envs/jon_current_env/lib/python3.11/site-packages/matplotlib/pyplot.py:464, in new_figure_manager(*args, **kwargs)
#     462 def new_figure_manager(*args, **kwargs):
#     463     """Create a new figure manager instance."""
# --> 464     _warn_if_gui_out_of_main_thread()
#     465     return _get_backend_mod().new_figure_manager(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/jon_current_env/lib/python3.11/site-packages/matplotlib/pyplot.py:441, in _warn_if_gui_out_of_main_thread()
#     439 def _warn_if_gui_out_of_main_thread() -> None:
#     440     warn = False
# --> 441     canvas_class = cast(type[FigureCanvasBase], _get_backend_mod().FigureCanvas)
#     442     if canvas_class.required_interactive_framework:
#     443         if hasattr(threading, 'get_native_id'):
#     444             # This compares native thread ids because even if Python-level
#     445             # Thread objects match, the underlying OS thread (which is what
#     446             # really matters) may be different on Python implementations with
#     447             # green threads.
#
# File ~/opt/miniconda3/envs/jon_current_env/lib/python3.11/site-packages/matplotlib/pyplot.py:280, in _get_backend_mod()
#     271 """
#     272 Ensure that a backend is selected and return it.
#     273
#     274 This is currently private, but may be made public in the future.
#     275 """
#     276 if _backend_mod is None:
#     277     # Use rcParams._get("backend") to avoid going through the fallback
#     278     # logic (which will (re)import pyplot and then call switch_backend if
#     279     # we need to resolve the auto sentinel)
# --> 280     switch_backend(rcParams._get("backend"))  # type: ignore[attr-defined]
#     281 return cast(type[matplotlib.backend_bases._Backend], _backend_mod)
#
# File ~/opt/miniconda3/envs/jon_current_env/lib/python3.11/site-packages/matplotlib/pyplot.py:342, in switch_backend(newbackend)
#     339 # have to escape the switch on access logic
#     340 old_backend = dict.__getitem__(rcParams, 'backend')
# --> 342 module = importlib.import_module(cbook._backend_module_name(newbackend))
#     343 canvas_class = module.FigureCanvas
#     345 required_framework = canvas_class.required_interactive_framework
#
# File ~/opt/miniconda3/envs/jon_current_env/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1126, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/opt/miniconda3/envs/jon_current_env/lib/python3.11/site-packages/matplotlib_inline/__init__.py:1
# ----> 1 from . import backend_inline, config  # noqa
#       2 __version__ = "0.1.6"
#
# File ~/opt/miniconda3/envs/jon_current_env/lib/python3.11/site-packages/matplotlib_inline/backend_inline.py:228
#     224                 ip.events.unregister('post_run_cell', configure_once)
#     225             ip.events.register('post_run_cell', configure_once)
# --> 228 _enable_matplotlib_integration()
#     231 def _fetch_figure_metadata(fig):
#     232     """Get some metadata to help with displaying a figure."""
#
# File ~/opt/miniconda3/envs/jon_current_env/lib/python3.11/site-packages/matplotlib_inline/backend_inline.py:218, in _enable_matplotlib_integration()
#     216 try:
#     217     activate_matplotlib(backend)
# --> 218     configure_inline_support(ip, backend)
#     219 except (ImportError, AttributeError):
#     220     # bugs may cause a circular import on Python 2
#     221     def configure_once(*args):
#
# File ~/opt/miniconda3/envs/jon_current_env/lib/python3.11/site-packages/matplotlib_inline/backend_inline.py:174, in configure_inline_support(shell, backend)
#     162 """Configure an IPython shell object for matplotlib use.
#     163
#     164 Parameters
#    (...)
#     168 backend : matplotlib backend
#     169 """
#     170 # If using our svg payload backend, register the post-execution
#     171 # function that will pick up the results for display.  This can only be
#     172 # done with access to the real shell object.
# --> 174 cfg = InlineBackend.instance(parent=shell)
#     175 cfg.shell = shell
#     176 if cfg not in shell.configurables:
#
# File ~/opt/miniconda3/envs/jon_current_env/lib/python3.11/site-packages/traitlets/config/configurable.py:552, in SingletonConfigurable.instance(cls, *args, **kwargs)
#     550 # Create and save the instance
#     551 if cls._instance is None:
# --> 552     inst = cls(*args, **kwargs)
#     553     # Now make sure that the instance will also be returned by
#     554     # parent classes' _instance attribute.
#     555     for subclass in cls._walk_mro():
#
# File ~/opt/miniconda3/envs/jon_current_env/lib/python3.11/site-packages/traitlets/config/configurable.py:110, in Configurable.__init__(self, **kwargs)
#     101 # load config
#     102 if config is not None:
#     103     # We used to deepcopy, but for now we are trying to just save
#     104     # by reference.  This *could* have side effects as all components
#    (...)
#     108     # making that a class attribute.
#     109     # self.config = deepcopy(config)
# --> 110     self.config = config
#     111 else:
#     112     # allow _config_default to return something
#     113     self._load_config(self.config)
#
# File ~/opt/miniconda3/envs/jon_current_env/lib/python3.11/site-packages/traitlets/traitlets.py:729, in TraitType.__set__(self, obj, value)
#     727     raise TraitError('The "%s" trait is read-only.' % self.name)
#     728 else:
# --> 729     self.set(obj, value)
#
# File ~/opt/miniconda3/envs/jon_current_env/lib/python3.11/site-packages/traitlets/traitlets.py:718, in TraitType.set(self, obj, value)
#     714     silent = False
#     715 if silent is not True:
#     716     # we explicitly compare silent to True just in case the equality
#     717     # comparison above returns something other than True/False
# --> 718     obj._notify_trait(self.name, old_value, new_value)
#
# File ~/opt/miniconda3/envs/jon_current_env/lib/python3.11/site-packages/traitlets/traitlets.py:1501, in HasTraits._notify_trait(self, name, old_value, new_value)
#    1500 def _notify_trait(self, name, old_value, new_value):
# -> 1501     self.notify_change(
#    1502         Bunch(
#    1503             name=name,
#    1504             old=old_value,
#    1505             new=new_value,
#    1506             owner=self,
#    1507             type="change",
#    1508         )
#    1509     )
#
# File ~/opt/miniconda3/envs/jon_current_env/lib/python3.11/site-packages/traitlets/traitlets.py:1513, in HasTraits.notify_change(self, change)
#    1511 def notify_change(self, change):
#    1512     """Notify observers of a change event"""
# -> 1513     return self._notify_observers(change)
#
# File ~/opt/miniconda3/envs/jon_current_env/lib/python3.11/site-packages/traitlets/traitlets.py:1560, in HasTraits._notify_observers(self, event)
#    1557 elif isinstance(c, EventHandler) and c.name is not None:
#    1558     c = getattr(self, c.name)
# -> 1560 c(event)
#
# File ~/opt/miniconda3/envs/jon_current_env/lib/python3.11/site-packages/traitlets/traitlets.py:1142, in observe_compat.<locals>.compatible_observer(self, change_or_name, old, new)
#    1130     warn(
#    1131         "A parent of %s._%s_changed has adopted the new (traitlets 4.1) @observe(change) API"
#    1132         % (clsname, change_or_name),
#    1133         DeprecationWarning,
#    1134     )
#    1135     change = Bunch(
#    1136         type="change",
#    1137         old=old,
#    (...)
#    1140         owner=self,
#    1141     )
# -> 1142 return func(self, change)
#
# File ~/opt/miniconda3/envs/jon_current_env/lib/python3.11/site-packages/traitlets/config/configurable.py:219, in Configurable._config_changed(self, change)
#     215 # We auto-load config section for this class as well as any parent
#     216 # classes that are Configurable subclasses.  This starts with Configurable
#     217 # and works down the mro loading the config for each section.
#     218 section_names = self.section_names()
# --> 219 self._load_config(change.new, traits=traits, section_names=section_names)
#
# File ~/opt/miniconda3/envs/jon_current_env/lib/python3.11/site-packages/traitlets/config/configurable.py:168, in Configurable._load_config(self, cfg, section_names, traits)
#     165 my_config = self._find_my_config(cfg)
#     167 # hold trait notifications until after all config has been loaded
# --> 168 with self.hold_trait_notifications():
#     169     for name, config_value in my_config.items():
#     170         if name in traits:
#
# File ~/opt/miniconda3/envs/jon_current_env/lib/python3.11/contextlib.py:144, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     142 if typ is None:
#     143     try:
# --> 144         next(self.gen)
#     145     except StopIteration:
#     146         return False
#
# File ~/opt/miniconda3/envs/jon_current_env/lib/python3.11/site-packages/traitlets/traitlets.py:1498, in HasTraits.hold_trait_notifications(self)
#    1496 for changes in cache.values():
#    1497     for change in changes:
# -> 1498         self.notify_change(change)
#
# File ~/opt/miniconda3/envs/jon_current_env/lib/python3.11/site-packages/traitlets/traitlets.py:1513, in HasTraits.notify_change(self, change)
#    1511 def notify_change(self, change):
#    1512     """Notify observers of a change event"""
# -> 1513     return self._notify_observers(change)
#
# File ~/opt/miniconda3/envs/jon_current_env/lib/python3.11/site-packages/traitlets/traitlets.py:1539, in HasTraits._notify_observers(self, event)
#    1537 class_value = getattr(self.__class__, magic_name)
#    1538 if not isinstance(class_value, ObserveHandler):
# -> 1539     _deprecated_method(
#    1540         class_value,
#    1541         self.__class__,
#    1542         magic_name,
#    1543         "use @observe and @unobserve instead.",
#    1544     )
#    1545     cb = getattr(self, magic_name)
#    1546     # Only append the magic method if it was not manually registered
#
# File ~/opt/miniconda3/envs/jon_current_env/lib/python3.11/site-packages/traitlets/traitlets.py:216, in _deprecated_method(method, cls, method_name, msg)
#     214     warn(warn_msg + ("\n(inspection failed) %s" % e), DeprecationWarning)
#     215 else:
# --> 216     warn_explicit(warn_msg, DeprecationWarning, fname, lineno)
#
# DeprecationWarning: InlineBackend._figure_formats_changed is deprecated in traitlets 4.1: use @observe and @unobserve instead.

# %% [markdown]
# Zoomed in, somewhat:

# %%
fig = plt.figure(figsize=(12, 6))

gs = fig.add_gridspec(2, 2, height_ratios=(1, 1), width_ratios=(4.5, 1), wspace=0.15, hspace=0.6)

# Phase

gs_1 = gs[0].subgridspec(1, 2, width_ratios=(1, 6), wspace=0.05)
gs_2 = gs[2].subgridspec(1, 2, width_ratios=(1, 6), wspace=0.05)

ax_1 = fig.add_subplot(gs_1[1])
ax_temp_1 = fig.add_subplot(gs_1[0], sharey=ax_1)
_plot_example(ax_1, ax_temp_1, models[0], tmax=90)


ax_2 = fig.add_subplot(gs_2[1])
ax_temp_2 = fig.add_subplot(gs_2[0], sharey=ax_2)
_plot_example(ax_2, ax_temp_2, models[10], tmax=90)

ax_temp_1.annotate('A', xy=(-0.04, np.pi*1.1), fontsize=14, annotation_clip=False)
ax_temp_2.annotate('B', xy=(-0.04, np.pi*1.1), fontsize=14, annotation_clip=False)

# Rose

ax_1p = fig.add_subplot(gs[1], projection='polar')
model = models[0]
start_from = model.ts[list(sorted(model.idx_event))[4*NOME_MEASURES - 1]]
ts = all_ts[0][np.where(all_ts[0] > start_from)[0]]
_plot_rose(ax_1p, ts, 'slategrey')

ax_2p = fig.add_subplot(gs[3], projection='polar')
model = models[10]
start_from = model.ts[list(sorted(model.idx_event))[4*NOME_MEASURES - 1]]
ts = all_ts[10][np.where(all_ts[10] > start_from)[0]]
_plot_rose(ax_2p, ts, 'slategrey')


fig.tight_layout()

plt.subplots_adjust(top=1.1)

fig.savefig('figures/fig_phasereset_examples.pdf', bbox_inches='tight');
pass
